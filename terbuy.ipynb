# %%
# !pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='127.0.0.1', database='TerpBuy', user='root', password='Hoki7122@')

# %%
import pandas as pd

# %%
df_qtsold=pd.read_sql('SELECT quantity_sold, department_name\
                      FROM order_line, department', conn)
df_qtsold
# Out:
# C:\Users\deole\AppData\Local\Temp\ipykernel_11776\180117076.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_qtsold=pd.read_sql('SELECT quantity_sold, department_name\
#        quantity_sold     department_name
# 0                  1  Health and Beauty
# 1                  1            Pet Shop
# 2                  1          Technology
# 3                  1          Discs Shop
# 4                  1           Book Shop
# ...              ...                 ...
# 57391              1                Golf
# 57392              1             Apparel
# 57393              1            Footwear
# 57394              1             Fitness
# 57395              1             Indoors
#
# [57396 rows x 2 columns]

# %%
### Q2--Using the query you wrote in Question 1, create a data visualization (e.g., a bar chart) 
###showing all departments and the number of items each of them sold. 
###Using a markdown cell, explain what you observe from the analysis.
import matplotlib.pyplot as plt

# %%
df1=df_qtsold.value_counts().to_frame()
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='quantity_sold,department_name'>

# %%
###Q3--Write a query to show the number of orders placed in each year in which at least one order was placed. 
###Hint: Search online to learn about MySQL’s YEAR() function to query data.

# %%
df2=pd.read_sql('select count(order_id), order_date\
                from orders\
                group by order_date', conn)
df2
# Out:
# C:\Users\deole\AppData\Local\Temp\ipykernel_11776\1958818148.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df2=pd.read_sql('select count(order_id), order_date\
#      count(order_id)  order_date
# 0                  3  2018-10-23
# 1                 10  2018-10-24
# 2                  6  2018-10-25
# 3                  7  2018-10-26
# 4                  6  2018-10-27
# ..               ...         ...
# 223               11  2021-01-26
# 224                4  2021-01-27
# 225               10  2021-01-28
# 226               19  2021-01-29
# 227               14  2021-01-30
#
# [228 rows x 2 columns]

# %%
###Q4--Using the query you wrote in Question 3, create a data visualization (e.g., a line graph) showing all years and the number of orders placed during each year, to see if there is a trend in ordering. Using a markdown cell, explain what you observe from the analysis.
df2.plot(kind='line')
# Out:
# <Axes: >
